# %%
# !nvidia-smi
# Out:
# Mon Mar  7 06:21:07 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install timm
# !pip3 install torchio
# !pip3 install omegaconf
# !pip3 install mmcv
# Out:
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 3.2 MB/s
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.11.1+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.5)
# Installing collected packages: timm
# Successfully installed timm-0.5.4
# Collecting torchio
#   Downloading torchio-0.18.74-py2.py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 3.3 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchio) (4.63.0)
# Requirement already satisfied: torch>=1.1 in /usr/local/lib/python3.7/dist-packages (from torchio) (1.10.0+cu111)
# Requirement already satisfied: humanize in /usr/local/lib/python3.7/dist-packages (from torchio) (0.5.1)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.7/dist-packages (from torchio) (3.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torchio) (1.4.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from torchio) (1.21.5)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from torchio) (7.1.2)
# Collecting SimpleITK!=2.0.*
#   Downloading SimpleITK-2.1.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (48.4 MB)
#      |████████████████████████████████| 48.4 MB 26 kB/s
# Collecting Deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.1->torchio) (3.10.0.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from Deprecated->torchio) (1.13.3)
# Installing collected packages: SimpleITK, Deprecated, torchio
# Successfully installed Deprecated-1.2.13 SimpleITK-2.1.1 torchio-0.18.74
# Collecting omegaconf
#   Downloading omegaconf-2.1.1-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 2.0 MB/s
# Collecting antlr4-python3-runtime==4.8
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      |████████████████████████████████| 112 kB 15.1 MB/s
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 37.5 MB/s
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141230 sha256=abdd4edb9d36a79fcd5665b8a9831ffd1701d88027c6935ba532069d73d5f0a8
#   Stored in directory: /root/.cache/pip/wheels/ca/33/b7/336836125fc9bb4ceaa4376d8abca10ca8bc84ddc824baea6c
# Successfully built antlr4-python3-runtime
# Installing collected packages: PyYAML, antlr4-python3-runtime, omegaconf
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 antlr4-python3-runtime-4.8 omegaconf-2.1.1
# Collecting mmcv
#   Downloading mmcv-1.4.6.tar.gz (438 kB)
#      |████████████████████████████████| 438 kB 4.0 MB/s
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mmcv) (1.21.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mmcv) (21.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from mmcv) (7.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from mmcv) (6.0)
# Collecting yapf
#   Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      |████████████████████████████████| 190 kB 43.6 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mmcv) (3.0.7)
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (setup.py) ... done
#   Created wheel for mmcv: filename=mmcv-1.4.6-py2.py3-none-any.whl size=656045 sha256=820c16813e6e513bfdbd4191179aa519337503395b4a6750c373a1fc7c64daf2
#   Stored in directory: /root/.cache/pip/wheels/4b/dc/28/f5fdb35b7e1a5f50de1a95a49e5f661e4ffb10461d35974240
# Successfully built mmcv
# Installing collected packages: yapf, addict, mmcv
# Successfully installed addict-2.4.0 mmcv-1.4.6 yapf-0.32.0

# %%
# %cd '/content/drive/MyDrive/COViT++'
import os
import time
import random
import math
import torch
import numpy as np
from omegaconf import OmegaConf

import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

from model.linear_super import LinearSuper
from model.lrsa_super import AttentionSuper
from model.layernorm_super import LayerNormSuper
from model.embedding_super import OverlapPatchembedSuper

from model.tfm_encoder_super import TransformerEncoderLayer

from model.supernet import PVTSuper
from supernet_train.supernet_engine import engine

from dataloader_n_aug.dataloader import get_test_data

from utils.utils import *
from utils.metric import MetricTracker
from utils.flops import get_flops
# Out:
# /content/drive/MyDrive/COViT++
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'

# %% [markdown]
# # SUPERNET

# %%
torch.cuda.empty_cache()
engine()

# %% [markdown]
# # EVOLUTION

# %%
cwd = os.getcwd()
config_file = 'config/config.yml'
model_config_file = 'config/model_cfg_evolution.yml'

metric_ftns = ['loss', 'acc']
train_metrics = MetricTracker(*[m for m in metric_ftns], mode='train')
valid_metrics = MetricTracker(*[m for m in metric_ftns], mode='validation')

config = OmegaConf.load((os.path.join(cwd, config_file)))['config']
model_cfg = OmegaConf.load((os.path.join(cwd, model_config_file)))

seeding(config)

# %%
cudnn.benchmark = True

data_loader_val = get_test_data(config)

model = PVTSuper(img_size=model_cfg.input_size,
                                    super_embed_dims=model_cfg.SUPERNET.EMBED_DIMS,\
                                    sample_embed_dims=model_cfg.SUPERNET.EMBED_DIMS,
                                    depths=model_cfg.SUPERNET.DEPTHS,
                                    mlp_ratios=model_cfg.SUPERNET.MLP_RATIOS,
                                    qkv_bias=True,
                                    drop_rate=model_cfg.drop_rate,
                                    attn_drop_rate=model_cfg.attn_drop_rate,
                                    num_classes=config.dataset.num_classes,
                                    num_stages=4)

choices = {'sample_pooling_dim': model_cfg.SEARCH_SPACE.SAMPLE_POOLING_DIM,
               'embed_dims': model_cfg.SEARCH_SPACE.EMBED_DIMS , 'depths': model_cfg.SEARCH_SPACE.DEPTHS}
# Out:
# Collecting data from : /content/drive/MyDrive/COViT++/data/test_split.txt
# Data collected! /content/drive/MyDrive/COViT++/data/test_split.txt
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
checkpoint_loader = torch.load(config.resume_training_dir, map_location='cpu')
checkpoint = model.state_dict()

for k, v in checkpoint_loader['model'].items():
    k = k.replace('module.', '')
    checkpoint.update({k: v})

model.load_state_dict(checkpoint, strict=True)

if not os.path.exists(config.resume_training):
    raise ("File doesn't exist {}".format(config.resume_training))

# %%
torch.manual_seed(48)
np.random.seed(48)
random.seed(48)

if (config.cuda):
    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")
else:
    device = torch.device("cpu")

model.to(device)
# Out:
# PVTSuper(
#   (patch_embed1): OverlapPatchembedSuper(
#     (proj): Conv2d(3, 32, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3))
#     (norm): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#   )
#   (block1): ModuleList(
#     (0): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=32, out_features=32, bias=True)
#         (kv): LinearSuper(in_features=32, out_features=64, bias=True)
#         (proj): LinearSuper(in_features=32, out_features=32, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=32, out_features=256, bias=True)
#         (dwconv): DWConv(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=256, out_features=32, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (1): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=32, out_features=32, bias=True)
#         (kv): LinearSuper(in_features=32, out_features=64, bias=True)
#         (proj): LinearSuper(in_features=32, out_features=32, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=32, out_features=256, bias=True)
#         (dwconv): DWConv(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=256, out_features=32, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (2): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=32, out_features=32, bias=True)
#         (kv): LinearSuper(in_features=32, out_features=64, bias=True)
#         (proj): LinearSuper(in_features=32, out_features=32, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((32,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=32, out_features=256, bias=True)
#         (dwconv): DWConv(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=256, out_features=32, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (norm1): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#   (patch_embed2): OverlapPatchembedSuper(
#     (proj): Conv2d(32, 64, kernel_size=(5, 5), stride=(3, 3), padding=(2, 2))
#     (norm): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (block2): ModuleList(
#     (0): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=64, out_features=64, bias=True)
#         (kv): LinearSuper(in_features=64, out_features=128, bias=True)
#         (proj): LinearSuper(in_features=64, out_features=64, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=64, out_features=512, bias=True)
#         (dwconv): DWConv(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=512, out_features=64, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (1): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=64, out_features=64, bias=True)
#         (kv): LinearSuper(in_features=64, out_features=128, bias=True)
#         (proj): LinearSuper(in_features=64, out_features=64, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=64, out_features=512, bias=True)
#         (dwconv): DWConv(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=512, out_features=64, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (2): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=64, out_features=64, bias=True)
#         (kv): LinearSuper(in_features=64, out_features=128, bias=True)
#         (proj): LinearSuper(in_features=64, out_features=64, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=64, out_features=512, bias=True)
#         (dwconv): DWConv(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=512, out_features=64, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (3): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=64, out_features=64, bias=True)
#         (kv): LinearSuper(in_features=64, out_features=128, bias=True)
#         (proj): LinearSuper(in_features=64, out_features=64, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((64,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=64, out_features=512, bias=True)
#         (dwconv): DWConv(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=512, out_features=64, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (norm2): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#   (patch_embed3): OverlapPatchembedSuper(
#     (proj): Conv2d(64, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#   )
#   (block3): ModuleList(
#     (0): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (1): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (2): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (3): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (4): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (8): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (9): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (10): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (11): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=160, out_features=160, bias=True)
#         (kv): LinearSuper(in_features=160, out_features=320, bias=True)
#         (proj): LinearSuper(in_features=160, out_features=160, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(160, 160, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((160,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=160, out_features=1280, bias=True)
#         (dwconv): DWConv(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1280, out_features=160, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (norm3): LayerNorm((160,), eps=1e-06, elementwise_affine=True)
#   (patch_embed4): OverlapPatchembedSuper(
#     (proj): Conv2d(160, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (norm): LayerNormSuper((256,), eps=1e-05, elementwise_affine=True)
#   )
#   (block4): ModuleList(
#     (0): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((256,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=256, out_features=256, bias=True)
#         (kv): LinearSuper(in_features=256, out_features=512, bias=True)
#         (proj): LinearSuper(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((256,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((256,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=256, out_features=1024, bias=True)
#         (dwconv): DWConv(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1024, out_features=256, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (1): TransformerEncoderLayer(
#       (norm1): LayerNormSuper((256,), eps=1e-05, elementwise_affine=True)
#       (attn): AttentionSuper(
#         (q): LinearSuper(in_features=256, out_features=256, bias=True)
#         (kv): LinearSuper(in_features=256, out_features=512, bias=True)
#         (proj): LinearSuper(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (sr): Conv2D(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (norm): LayerNormSuper((256,), eps=1e-05, elementwise_affine=True)
#         (act): GELU()
#       )
#       (norm2): LayerNormSuper((256,), eps=1e-05, elementwise_affine=True)
#       (mlp): MlpSuper(
#         (fc1): LinearSuper(in_features=256, out_features=1024, bias=True)
#         (dwconv): DWConv(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#         (act): GELU()
#         (fc2): LinearSuper(in_features=1024, out_features=256, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (norm4): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#   (head): LastMLP(
#     (classifier): Sequential(
#       (0): Linear(in_features=256, out_features=64, bias=True)
#       (1): GELU()
#       (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=64, out_features=16, bias=True)
#       (5): GELU()
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): Dropout(p=0.3, inplace=False)
#       (8): Linear(in_features=16, out_features=3, bias=True)
#     )
#   )
# )

# %%
from evo_search import EvolutionSearch

t = time.time()

searcher = EvolutionSearch(config=model_cfg, main_config=config, model=model, choices=choices, test_loader=data_loader_val)
searcher.search()

print('Total searching time = {:.2f} hours'.format((time.time() - t) / 3600))
# Out:
#  + population_num = 50
#  + select_num = 10
#  + mutation_num = 25
#  + crossover_num = 25
#  + random_num = 0
#  + max_epochs = 100
# Random select ........
# Rank: 0 (31, 2, 3, 6, 2, 16, 32, 80, 128) 5.198435
#  - Sampled model config: {'depths': [2, 3, 6, 2], 'embed_dims': [16, 32, 80, 128], 'sample_pooling_dim': 31}
#  - Sampled model parameters: 5198435
# Evaluate for epoch 0:   0%|          | 0/14 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/drive/MyDrive/COViT++/supernet_train/supernet_train.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   ground_truths = torch.tensor(targets, dtype=torch.long).to(device, non_blocking=True)
# /content/drive/MyDrive/COViT++/supernet_train/supernet_train.py:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   predictions = torch.tensor(torch.argmax(outputs, dim=1), dtype=torch.float32)
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:51<00:00,  3.65s/it]
# Evaluate for epoch 0:   0%|          | 0/14 [00:00<?, ?it/s]
# validation Summary  Epoch: [0/30]	 loss  1.6500	acc  0.2888
# Sens: [1.   0.16 0.  ] , PPV: [0.27061856 0.516129   0.        ]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# /usr/local/lib/python3.7/dist-packages/mmcv/cnn/utils/flops_counter.py:535: UserWarning: variables __flops__ or __params__ are already defined for the moduleLinear ptflops can affect your code!
#   ' ptflops can affect your code!')
# /usr/local/lib/python3.7/dist-packages/mmcv/cnn/utils/flops_counter.py:535: UserWarning: variables __flops__ or __params__ are already defined for the moduleBatchNorm1d ptflops can affect your code!
#   ' ptflops can affect your code!')
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:24<00:00,  1.78s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:24<00:00,  1.78s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:24<00:00,  1.78s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:24<00:00,  1.78s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:24<00:00,  1.78s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:24<00:00,  1.78s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:24<00:00,  1.78s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.79s/it]
# Evaluate for epoch 0: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:27<00:00,  1.93s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.80s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 1: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 2: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:27<00:00,  1.97s/it]
# Evaluate for epoch 3: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 4: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:27<00:00,  1.96s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.93s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 5: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:25<00:00,  1.86s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:27<00:00,  1.96s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:25<00:00,  1.81s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 6: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:27<00:00,  1.93s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:25<00:00,  1.86s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:27<00:00,  1.93s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 7: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:25<00:00,  1.82s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:27<00:00,  1.93s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:27<00:00,  1.96s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 8: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:27<00:00,  1.97s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:27<00:00,  1.93s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:27<00:00,  1.96s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:27<00:00,  1.97s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:27<00:00,  1.93s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:27<00:00,  1.96s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.93s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 9: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.93s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:27<00:00,  1.96s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.91s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:27<00:00,  1.97s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 10: 100%|██████████| 14/14 [00:26<00:00,  1.86s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.92s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.90s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.87s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.97s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.97s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.97s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.89s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.93s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.97s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:25<00:00,  1.83s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:25<00:00,  1.85s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:25<00:00,  1.84s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.94s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.96s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.97s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.88s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:27<00:00,  1.95s/it]
# Evaluate for epoch 11: 100%|██████████| 14/14 [00:26<00:00,  1.93s/it]
# Evaluate for epoch 12: 100%|██████████| 14/14 [00:27<00:00,  1.93s/it]
# Evaluate for epoch 12:  36%|███▌      | 5/14 [00:19<00:35,  3.91s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-35b5dc1a16f2> in <module>()
#       4
#       5 searcher = EvolutionSearch(config=model_cfg, main_config=config, model=model, choices=choices, test_loader=data_loader_val)
# ----> 6 searcher.search()
#       7
#       8 print('Total searching time = {:.2f} hours'.format((time.time() - t) / 3600))
#
# /content/drive/MyDrive/COViT++/evo_search.py in search(self)
#     319                 self.select_num, self.mutation_num, self.m_prob, self.s_prob)
#     320
# --> 321             crossover = self.get_crossover(self.select_num, self.crossover_num)
#     322
#     323             if  self.epoch < 1:
#
# /content/drive/MyDrive/COViT++/evo_search.py in get_crossover(self, k, crossover_num)
#     271             max_iters -= 1
#     272             cand = next(cand_iter)
# --> 273             if not self.is_legal(cand):
#     274                 continue
#     275             res.append(cand)
#
# /content/drive/MyDrive/COViT++/evo_search.py in is_legal(self, cand)
#     145
#     146         val_loss, val_acc, s, ppv , _ = evaluate(self.test_loader, self.model, self.device, self.valid_metrics, epoch=self.epoch,\
# --> 147                          mode='retrain', choices=self.choices, retrain_config=sampled_config, config=self.main_config)
#     148
#     149         info['test_acc'] = val_acc
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /content/drive/MyDrive/COViT++/supernet_train/supernet_train.py in evaluate(data_loader, model, device, valid_metrics, epoch, mode, choices, retrain_config, config)
#     114
#     115
# --> 116     for batch_idx, (images, targets) in enumerate(tqdm(data_loader, desc=f'Evaluate for epoch {epoch}')):
#     117         images = images.to(device, non_blocking=True)
#     118         ground_truths = torch.tensor(targets, dtype=torch.long).to(device, non_blocking=True)
#
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py in __iter__(self)
#    1193
#    1194         try:
# -> 1195             for obj in iterable:
#    1196                 yield obj
#    1197                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1150         else:
#    1151             while True:
# -> 1152                 success, data = self._try_get_data()
#    1153                 if success:
#    1154                     return data
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     988         #   (bool: whether successfully get data, any: data if successful else None)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#     992         except Exception as e:
#
# /usr/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# /usr/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# /usr/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     919
#     920             while True:
# --> 921                 ready = selector.select(timeout)
#     922                 if ready:
#     923                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # PARETO FRONT
# **Flops, Params., Acc. and COVID-19-Sens.**

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import pandas as pd
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D


models_8844 = torch.load('/content/drive/MyDrive/COViT++/evo_output_dir/[8, 8, 4, 4]-checkpoint-100.pth')
models_8884 = torch.load('/content/drive/MyDrive/COViT++/evo_output_dir/[8, 8, 8, 4]-ULTIMATE.pth')

print('Number of 8-8-8-4 models: ', len(models_8884['vis_dict']))
print('Number of 8-8-4-4 models: ', len(models_8844['vis_dict']))
# Out:
# Number of 8-8-8-4 models:  393
# Number of 8-8-4-4 models:  542

# %%
def preprocess_visdict(input_dict):
    visited_dicts = dict()

    for k, v in input_dict.items():
        if len(k) == 9 and all(key in v for key in ('params', 'test_acc', 'visited', 'flops (G)', 'covid_sens')):
            visited_dicts.update({k: v})
    return visited_dicts


def process_df(input_dict):
    input_dict = preprocess_visdict(input_dict)
    return pd.DataFrame(input_dict).transpose()


def top_test_acc(processed_df, spec_a=False, spec_b=False, spec_a_ascending=False, spec_b_ascending=False, sort_2_specs=False):
    if sort_2_specs:
        return processed_df.sort_values([spec_a, spec_b], ascending=[spec_a_ascending, spec_b_ascending]).head(20)
    else:
        return processed_df.sort_values(spec_a, ascending=spec_a_ascending).head(20)


def plot_pareto_frontier(Xs, Ys, ax, maxX=True, maxY=True, titleX='', titleY=''):
    # Pareto frontier selection process
    sorted_list = sorted([[Xs[i], Ys[i]] for i in range(len(Xs))], reverse=maxX)
    pareto_front = [sorted_list[0]]
    for pair in sorted_list[1:]:
        if maxY:
            if pair[1] >= pareto_front[-1][1]:
                pareto_front.append(pair)
        else:
            if pair[1] <= pareto_front[-1][1]:
                pareto_front.append(pair)
    
    # Plotting process
    ax.scatter(Xs, Ys, label='Individual')
    pf_X = [pair[0] for pair in pareto_front]
    pf_Y = [pair[1] for pair in pareto_front]
    ax.plot(pf_X, pf_Y, '-r', label='Pareto Front', linewidth=3.0)
    ax.grid()

    ax.set_xlabel(titleX)
    ax.set_ylabel(titleY)
    ax.legend()
    


def plot_paretofront(processed_df):
    fig, axes = plt.subplots(2, 2, sharex=True, figsize=(14, 9))

    x = np.real(processed_df['params'])
    y = np.real(processed_df['flops (G)'])
    z = np.real(processed_df['test_acc'])
    t = np.real(processed_df['covid_sens'])

    plot_pareto_frontier(x, z, axes[0][0], maxX=False, maxY=True, titleX='params (M)', titleY='test_acc (%)')
    plot_pareto_frontier(y, z, axes[0][1], maxX=False, maxY=True, titleX='flops (G)', titleY='test_acc (%)')
    plot_pareto_frontier(x, t, axes[1][0], maxX=False, maxY=True, titleX='params (M)', titleY='covid_sens (%)')
    plot_pareto_frontier(y, t, axes[1][1], maxX=False, maxY=True, titleX='flops (G)', titleY='covid_sens (%)')

    fig.tight_layout()
    plt.show()

# %%
df_8884 = process_df(models_8884['vis_dict']).sort_values(['test_acc', 'covid_sens'], ascending=[False, False])

plot_paretofront(df_8884)

# %%
df_8844 = process_df(models_8844['vis_dict']).sort_values(['test_acc', 'covid_sens'], ascending=[False, False])

plot_paretofront(df_8844)

# %%
df_8884['8-8-8-4'] = True
df_8844['8-8-4-4'] = True

df_merged = pd.concat([df_8884, df_8844], ignore_index=False).fillna(False)[:100]

plot_paretofront(df_merged)

# %%
top_test_acc(df_merged, spec_a='params', spec_b='test_acc', spec_a_ascending=True, spec_b_ascending=False, sort_2_specs=True)
# Out:
#                              params  test_acc  covid_sens  flops (G)  visited  \
# 7  2 2 2  2 16 32 80  128  3.161987  0.598342    0.000000   0.295827     True
# 31 2 2 4  2 8  16 40  64   3.895987  0.596237    0.000000   0.706328     True
# 15 2 3 6  2 16 32 80  128  5.198435  0.599429    0.000000   0.444061     True
#             32 64 160 256  5.799043  0.602453    0.000000   0.635887     True
# 31 2 4 8  2 32 64 160 256  6.967939  0.600770    0.000000   3.162013     True
#      2 12 2 8  16 80  64   7.913747  0.600892    0.046729   3.800324     True
# 7  2 2 12 2 8  16 80  64   7.913747  0.593286    0.046729   2.987900     True
#             24 16 80  64   7.917939  0.596571    0.046729   3.007168     True
# 31 2 2 12 2 8  32 80  64   7.922035  0.599725    0.046729   3.854571     True
# 7  2 2 12 2 8  32 80  64   7.922035  0.598503    0.046729   2.990666     True
#             24 32 80  64   7.926227  0.596133    0.046729   3.009934     True
#                48 80  64   7.934515  0.600125    0.046729   3.012699     True
# 31 3 2 12 2 24 16 80  64   7.939035  0.600681    0.079439   8.124396     True
# 7  3 2 12 2 24 16 80  64   7.939035  0.596062    0.093458   6.950492     True
#             8  32 80  64   7.941035  0.605191    0.093458   6.521897     True
# 31 3 2 12 2 8  32 80  64   7.941035  0.603832    0.079439   7.388626     True
# 7  3 2 12 2 24 32 80  64   7.947323  0.599346    0.093458   6.953258     True
# 31 3 2 12 2 24 32 80  64   7.947323  0.599168    0.079439   8.178643     True
#             8  48 80  64   7.949323  0.603761    0.079439   7.442872     True
# 7  3 2 12 2 8  48 80  64   7.949323  0.595089    0.093458   6.524663     True
#
#                            8-8-8-4  8-8-4-4
# 7  2 2 2  2 16 32 80  128     True    False
# 31 2 2 4  2 8  16 40  64      True    False
# 15 2 3 6  2 16 32 80  128     True    False
#             32 64 160 256     True    False
# 31 2 4 8  2 32 64 160 256     True    False
#      2 12 2 8  16 80  64      True    False
# 7  2 2 12 2 8  16 80  64      True    False
#             24 16 80  64      True    False
# 31 2 2 12 2 8  32 80  64      True    False
# 7  2 2 12 2 8  32 80  64      True    False
#             24 32 80  64      True    False
#                48 80  64      True    False
# 31 3 2 12 2 24 16 80  64      True    False
# 7  3 2 12 2 24 16 80  64      True    False
#             8  32 80  64      True    False
# 31 3 2 12 2 8  32 80  64      True    False
# 7  3 2 12 2 24 32 80  64      True    False
# 31 3 2 12 2 24 32 80  64      True    False
#             8  48 80  64      True    False
# 7  3 2 12 2 8  48 80  64      True    False

# %%
df_merged[(df_merged['params'] > 3.0) & (df_merged['params'] < 6.5)]
# Out:
#                             params  test_acc  covid_sens  flops (G)  visited  \
# 15 2 3 6 2 32 64 160 256  5.799043  0.602453         0.0   0.635887     True
#            16 32 80  128  5.198435  0.599429         0.0   0.444061     True
# 7  2 2 2 2 16 32 80  128  3.161987  0.598342         0.0   0.295827     True
# 31 2 2 4 2 8  16 40  64   3.895987  0.596237         0.0   0.706328     True
#
#                           8-8-8-4  8-8-4-4
# 15 2 3 6 2 32 64 160 256     True    False
#            16 32 80  128     True    False
# 7  2 2 2 2 16 32 80  128     True    False
# 31 2 2 4 2 8  16 40  64      True    False

# %% [markdown]
# **Best model configuration:**
# (7,	2,	2,	2,	2,	16,	32,	80,	128)
